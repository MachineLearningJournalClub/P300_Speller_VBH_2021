# %%
import scipy.io
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
matrixodb = scipy.io.loadmat('./data/P1_odb.mat')
matrixstd = scipy.io.loadmat('./data/P1_std.mat')
P1odb = pd.DataFrame.from_dict(matrixodb['E_odb'])
P1std = pd.DataFrame.from_dict(matrixstd['E_std'])
P1odb['trig'] = np.ones((150))*1

# %%
P1std['trig'] = np.ones((1050))*-1

# %%
P1std
# Out:
#               0          1          2          3          4          5  \
# 0     13.841465  14.016478  13.608346  13.076333  13.132714  14.334297
# 1     -8.026854  -8.770455 -10.028952 -11.142821 -11.614986 -11.369499
# 2     -0.421857  -1.487404  -1.908706  -1.350003   0.246942   2.630587
# 3     -5.354894  -8.259110 -10.150105 -11.017689 -11.206920 -11.224907
# 4      7.557720   9.563675  10.701182  10.909864  10.404051   9.558844
# ...         ...        ...        ...        ...        ...        ...
# 1045   1.357398   2.466432   3.558555   4.602108   5.521307   6.151947
# 1046  -3.983711  -1.561955  -0.136934   0.471325   0.713084   1.160406
# 1047  10.598088   8.620539   5.841647   2.932392   0.648451  -0.444166
# 1048  -1.867614  -2.330385  -2.432316  -2.346067  -2.236152  -2.212695
# 1049 -10.145356 -10.303264  -8.984955  -6.472735  -3.493839  -0.942329
#
#               6          7          8          9  ...       1591      1592  \
# ...

# %%
df = pd.concat([P1odb, P1std])

# %%
df_shuffled = df.sample(frac=1, random_state=0)

# %%
df_shuffled
# Out:
#              0          1          2          3          4          5  \
# 48   -4.696610  -2.951480  -1.427365  -0.343443   0.098900  -0.212257
# 178  -0.082439  -2.183436  -4.974743  -8.158568 -11.165932 -13.443636
# 45    1.508828   1.234651   0.221487  -1.295342  -2.981779  -4.543641
# 113  14.790250  14.099578  12.519803  10.664440   9.190667   8.598516
# 471   6.679827   5.048925   2.550370  -0.289882  -2.906573  -4.855983
# ..         ...        ...        ...        ...        ...        ...
# 883  -3.276670  -8.473564 -13.004188 -16.047511 -17.293014 -16.942539
# 613  -9.002189 -11.106689 -13.527513 -15.977662 -18.054674 -19.356538
# 685  -2.226952  -1.986052  -1.440325  -0.704517  -0.058280   0.144256
# 409  -5.396713  -5.427996  -4.860049  -3.620983  -1.929825  -0.258308
# 534   4.415894   4.798125   5.378442   6.106857   6.801302   7.212802
#
#              6          7          8          9  ...       1591       1592  \
# ...

# %%
df_shuffled.to_csv('df1.csv')

# %%
matrixodb2 = scipy.io.loadmat('./data/P2_odb_down.mat')
matrixstd2 = scipy.io.loadmat('./data/P2_std_down.mat')
P2odb = pd.DataFrame.from_dict(matrixodb2['E_odb_down'])
P2std = pd.DataFrame.from_dict(matrixstd2['E_std_down'])
P2odb['trig'] = np.ones((150))*1
P2std['trig'] = np.ones((1050))*-1

# %%
df2 = pd.concat([P2odb, P2std])

# %%
df2_shuffled = df2.sample(frac=1, random_state=0)

# %%
#df2_shuffled

# %%
df2_shuffled.to_csv('df2.csv')

# %%
matrixodb3 = scipy.io.loadmat('./data/P3_odb_down.mat')
matrixstd3 = scipy.io.loadmat('./data/P3_std_down.mat')
P3odb = pd.DataFrame.from_dict(matrixodb3['E_odb_down'])
P3std = pd.DataFrame.from_dict(matrixstd3['E_std_down'])
P3odb['trig'] = np.ones((150))*1
P3std['trig'] = np.ones((1050))*-1

# %%
df3 = pd.concat([P3odb, P3std])

# %%
df3_shuffled = df3.sample(frac=1, random_state=0)

# %%
#df3_shuffled

# %%
df3_shuffled.to_csv('df3.csv')

# %%
matrixodb4 = scipy.io.loadmat('./data/P4_odb_down.mat')
matrixstd4 = scipy.io.loadmat('./data/P4_std_down.mat')
P4odb = pd.DataFrame.from_dict(matrixodb4['E_odb_down'])
P4std = pd.DataFrame.from_dict(matrixstd4['E_std_down'])
P4odb['trig'] = np.ones((150))*1
P4std['trig'] = np.ones((1050))*-1

# %%
df4 = pd.concat([P4odb, P4std])

# %%
df4_shuffled = df4.sample(frac=1, random_state=0)

# %%
df4_shuffled.to_csv('df4.csv')

# %%
matrixodb5 = scipy.io.loadmat('./data/P5_odb_down.mat')
matrixstd5 = scipy.io.loadmat('./data/P5_std_down.mat')
P5odb = pd.DataFrame.from_dict(matrixodb5['E_odb_down'])
P5std = pd.DataFrame.from_dict(matrixstd5['E_std_down'])
P5odb['trig'] = np.ones((150))*1
P5std['trig'] = np.ones((1050))*-1

# %%
df5 = pd.concat([P5odb, P5std])

# %%
df5_shuffled = df5.sample(frac=1, random_state=0)

# %%
df5_shuffled.to_csv('df5.csv')

# %%
#df5_shuffled
